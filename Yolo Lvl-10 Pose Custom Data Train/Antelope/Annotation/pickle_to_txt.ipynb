# %%
import os
import pickle

# Loop through all files in the current directory
for filename in os.listdir():
    if filename.endswith('.pickle'):
        # Load the pickle file
        with open(filename, 'rb') as pickle_file:
            data = pickle.load(pickle_file)
        # Create a corresponding text file name
        text_filename = filename.replace('.pickle', '.txt')

        # Write the contents to the text file
        with open(text_filename, 'w') as text_file:
            text_file.write(str(data))

        print(f'Converted {filename} to {text_filename}')
# Out:
# Converted antelope_10002.pickle to antelope_10002.txt
# Converted antelope_10003.pickle to antelope_10003.txt
# Converted antelope_10005.pickle to antelope_10005.txt
# Converted antelope_10007.pickle to antelope_10007.txt
# Converted antelope_10010.pickle to antelope_10010.txt
# Converted antelope_10011.pickle to antelope_10011.txt
# Converted antelope_10012.pickle to antelope_10012.txt
# Converted antelope_10013.pickle to antelope_10013.txt
# Converted antelope_10014.pickle to antelope_10014.txt
# Converted antelope_10015.pickle to antelope_10015.txt
# Converted antelope_10016.pickle to antelope_10016.txt
# Converted antelope_10018.pickle to antelope_10018.txt
# Converted antelope_10019.pickle to antelope_10019.txt
# Converted antelope_10020.pickle to antelope_10020.txt
# Converted antelope_10021.pickle to antelope_10021.txt
# Converted antelope_10023.pickle to antelope_10023.txt
# Converted antelope_10025.pickle to antelope_10025.txt
# Converted antelope_10027.pickle to antelope_10027.txt
# Converted antelope_10028.pickle to antelope_10028.txt
# Converted antelope_10029.pickle to antelope_10029.txt
# Converted antelope_10030.pickle to antelope_10030.txt
# Converted antelope_10031.pickle to antelope_10031.txt
# Converted antelope_10032.pickle to antelope_10032.txt
# Converted antelope_10035.pickle to antelope_10035.txt
# Converted antelope_10036.pickle to antelope_10036.txt
# Converted antelope_10037.pickle to antelope_10037.txt
# Converted antelope_10039.pickle to antelope_10039.txt
# Converted antelope_10040.pickle to antelope_10040.txt
# Converted antelope_10041.pickle to antelope_10041.txt
# Converted antelope_10044.pickle to antelope_10044.txt
# Converted antelope_10047.pickle to antelope_10047.txt
# Converted antelope_10052.pickle to antelope_10052.txt
# Converted antelope_10053.pickle to antelope_10053.txt
# Converted antelope_10054.pickle to antelope_10054.txt
# Converted antelope_10055.pickle to antelope_10055.txt
# Converted antelope_10059.pickle to antelope_10059.txt
# Converted antelope_10060.pickle to antelope_10060.txt
# Converted antelope_10061.pickle to antelope_10061.txt
# Converted antelope_10063.pickle to antelope_10063.txt
# Converted antelope_10064.pickle to antelope_10064.txt
# Converted antelope_10066.pickle to antelope_10066.txt
# Converted antelope_10067.pickle to antelope_10067.txt
# Converted antelope_10074.pickle to antelope_10074.txt
# Converted antelope_10075.pickle to antelope_10075.txt
# Converted antelope_10076.pickle to antelope_10076.txt
# Converted antelope_10077.pickle to antelope_10077.txt
# Converted antelope_10078.pickle to antelope_10078.txt
# Converted antelope_10079.pickle to antelope_10079.txt
# Converted antelope_10080.pickle to antelope_10080.txt
# Converted antelope_10081.pickle to antelope_10081.txt
# Converted antelope_10082.pickle to antelope_10082.txt
# Converted antelope_10083.pickle to antelope_10083.txt
# Converted antelope_10084.pickle to antelope_10084.txt
# Converted antelope_10085.pickle to antelope_10085.txt
# %%
import os

# Define the output directory
output_folder = './Yolo Annotations'

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# List of keypoints in the required order
keypoints_order = [
    "nose", "upper_jaw", "lower_jaw", "mouth_end_right", "mouth_end_left",
    "right_eye", "right_earbase", "right_earend", "right_antler_base", "right_antler_end",
    "left_eye", "left_earbase", "left_earend", "left_antler_base", "left_antler_end",
    "neck_base", "neck_end", "throat_base", "throat_end", "back_base",
    "back_end", "back_middle", "tail_base", "tail_end", "front_left_thai",
    "front_left_knee", "front_left_paw", "front_right_thai", "front_right_knee",
    "front_right_paw", "back_left_knee", "back_left_paw", "back_left_thai",
    "back_right_thai", "back_right_paw", "back_right_knee", "belly_bottom",
    "body_middle_right", "body_middle_left"
]

# Function to process each input annotation file and convert to YOLO format
def process_annotation_file(input_file, output_file):
    try:
        # Read the content of the input annotation file
        with open(input_file, 'r') as f:
            data = eval(f.read().strip())  # Read and convert the data to a dictionary

        if 'a1' not in data:
            print(f"Skipping {input_file}: Missing 'a1' data")
            return
        
        annotation = data['a1']
        
        # Extract bounding box
        bbox = annotation.get('bbox')
        if bbox:
            xtl, ytl, w, h = bbox
            # Assuming width and height (could be extracted if included in your text files)
            width = 1024  # Default width if not specified
            height = 768  # Default height if not specified

            # Normalize the bounding box
            cx = (xtl + w / 2) / width
            cy = (ytl + h / 2) / height
            norm_w = w / width
            norm_h = h / height
            normalized_bbox = [cx, cy, norm_w, norm_h]
        else:
            print(f"Skipping {input_file}: Missing bbox data")
            return

        # Extract keypoints and arrange them in the required order
        normalized_keypoints = []
        for key in keypoints_order:
            if key in annotation and isinstance(annotation[key], list) and len(annotation[key]) == 2:
                x, y = annotation[key]
                if x != -1 and y != -1:
                    norm_x = x / width
                    norm_y = y / height
                    v = 2  # Visible
                else:
                    norm_x = norm_y = 0
                    v = 0  # Not visible
            else:
                norm_x = norm_y = 0
                v = 0  # Not visible

            normalized_keypoints.append(f"{norm_x} {norm_y} {v}")

        # Create the YOLO formatted file and save
        with open(output_file, 'w') as tf:
            # Write class name (0 for pose detection class)
            tf.write(f"0 ")
            
            # Write bounding box
            tf.write(f"{' '.join(map(str, normalized_bbox))}")
            tf.write(f" ")
            
            # Write keypoints
            tf.write(' '.join(normalized_keypoints))

        print(f"Processed and saved {output_file}")

    except Exception as e:
        print(f"Error processing file {input_file}: {e}")

# Process all files in the current directory
def process_all_files():
    for filename in os.listdir('.'):
        if filename.endswith('.txt'):  # Assuming the input files are in TXT format
            input_file = os.path.join('.', filename)
            output_file = os.path.join(output_folder, os.path.splitext(filename)[0] + "_yolo.txt")
            process_annotation_file(input_file, output_file)

# Run the processing
process_all_files()

# %%
import os

# List of keypoints in the required order
keypoints_order = [
    "nose", "upper_jaw", "lower_jaw", "mouth_end_right", "mouth_end_left",
    "right_eye", "right_earbase", "right_earend", "right_antler_base", "right_antler_end",
    "left_eye", "left_earbase", "left_earend", "left_antler_base", "left_antler_end",
    "neck_base", "neck_end", "throat_base", "throat_end", "back_base",
    "back_end", "back_middle", "tail_base", "tail_end", "front_left_thai",
    "front_left_knee", "front_left_paw", "front_right_thai", "front_right_knee",
    "front_right_paw", "back_left_knee", "back_left_paw", "back_left_thai",
    "back_right_thai", "back_right_paw", "back_right_knee", "belly_bottom",
    "body_middle_right", "body_middle_left"
]

# Function to process each input annotation file and convert to YOLO format
def process_annotation_file(input_file, output_file):
    try:
        # Read the content of the input annotation file
        with open(input_file, 'r') as f:
            data = eval(f.read().strip())  # Read and convert the data to a dictionary

        if 'a1' not in data:
            print(f"Skipping {input_file}: Missing 'a1' data")
            return
        
        annotation = data['a1']
        
        # Extract bounding box
        bbox = annotation.get('bbox')
        if bbox:
            xtl, ytl, w, h = bbox
            # Assuming width and height (could be extracted if included in your text files)
            width = 1024  # Default width if not specified
            height = 768  # Default height if not specified

            # Normalize the bounding box
            cx = (xtl + w / 2) / width
            cy = (ytl + h / 2) / height
            norm_w = w / width
            norm_h = h / height
            normalized_bbox = [cx, cy, norm_w, norm_h]
        else:
            print(f"Skipping {input_file}: Missing bbox data")
            return

        # Extract keypoints and arrange them in the required order
        normalized_keypoints = []
        for key in keypoints_order:
            if key in annotation and isinstance(annotation[key], list) and len(annotation[key]) == 2:
                x, y = annotation[key]
                if x != -1 and y != -1:
                    norm_x = x / width
                    norm_y = y / height
                    v = 2  # Visible
                else:
                    norm_x = norm_y = 0
                    v = 0  # Not visible
            else:
                norm_x = norm_y = 0
                v = 0  # Not visible

            normalized_keypoints.append(f"{norm_x} {norm_y} {v}")

        # Create the YOLO formatted file and save
        with open(output_file, 'w') as tf:
            # Write class name (0 for pose detection class)
            tf.write(f"0 ")
            
            # Write bounding box
            tf.write(f"{' '.join(map(str, normalized_bbox))}")
            tf.write(f" ")
            
            # Write keypoints
            tf.write(' '.join(normalized_keypoints))

        print(f"Processed and saved {output_file}")

    except Exception as e:
        print(f"Error processing file {input_file}: {e}")

# Process all files in the current directory
def process_all_files():
    for filename in os.listdir('.'):
        if filename.endswith('.txt'):  # Assuming the input files are in TXT format
            input_file = os.path.join('.', filename)
            output_file = os.path.splitext(filename)[0] + ".txt"
            process_annotation_file(input_file, output_file)

# Run the processing
process_all_files()
# Out:
# Processed and saved antelope_10002.txt
# Processed and saved antelope_10003.txt
# Processed and saved antelope_10005.txt
# Processed and saved antelope_10007.txt
# Processed and saved antelope_10010.txt
# Processed and saved antelope_10011.txt
# Processed and saved antelope_10012.txt
# Processed and saved antelope_10013.txt
# Processed and saved antelope_10014.txt
# Processed and saved antelope_10015.txt
# Processed and saved antelope_10016.txt
# Processed and saved antelope_10018.txt
# Processed and saved antelope_10019.txt
# Processed and saved antelope_10020.txt
# Processed and saved antelope_10021.txt
# Processed and saved antelope_10023.txt
# Processed and saved antelope_10025.txt
# Processed and saved antelope_10027.txt
# Processed and saved antelope_10028.txt
# Processed and saved antelope_10029.txt
# Processed and saved antelope_10030.txt
# Processed and saved antelope_10031.txt
# Processed and saved antelope_10032.txt
# Processed and saved antelope_10035.txt
# Processed and saved antelope_10036.txt
# Processed and saved antelope_10037.txt
# Processed and saved antelope_10039.txt
# Processed and saved antelope_10040.txt
# Processed and saved antelope_10041.txt
