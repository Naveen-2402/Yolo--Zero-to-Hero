# %%
# !nvidia-smi
# Out:
# Thu Dec 26 09:37:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P0              35W /  70W |      0MiB / 15360MiB |     23%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect  mode=predict model=yolov8l.pt conf=0.25 source="https://ultralytics.com/images/bus.jpg"  # checking yolo is working

# %% [markdown]
# #**Custom Data** **Training**

# %%
# !yolo task=detect mode=train model=yolov8l.pt data="../content/drive/MyDrive/Construction Safety/data.yaml" epochs=50 imgsz=640

# task=detect: Specifies that the task is object detection.
# mode=train: Indicates the model is in training mode.
# model=yolov8l.pt: Uses the YOLOv8 large pre-trained model as a starting point.
# data="../content/drive/MyDrive/Construction Safety/data.yaml": path to data.yaml (which has the execution commands).
# epochs=50: The model will go through the entire dataset 50 times during training.
# imgsz=640: All images will be resized to 640x640 pixels for training.
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
